# %%
import librosa
import librosa.display
import IPython.display as ipd
import numpy as np
import matplotlib.pyplot as plt
import os
from sklearn.metrics import silhouette_score
from sklearn.cluster import KMeans
import warnings
warnings.filterwarnings("ignore")

# %%
from helpers.librosaHelper import LibrosaHelpers
from cluster.musicCluster import MusicCluster

# %%
PATH='data/'

# %%
os.listdir(PATH)
# Out:
# ['0 Maroon 5 - Girls Like You ft. Cardi B (Volume 2) (Official Music Video).mp3',
#  '1 debussy.wav',
#  '2 queen.wav',
#  '3 Wiz Khalifa - See You Again ft. Charlie Puth [Official Video] Furious 7 Soundtrack.mp3',
#  '4 ZAYN - Dusk Till Dawn (Official Video) ft. Sia.mp3',
#  "5 James Arthur - Say You Won't Let Go.mp3",
#  '6 seeyouagain.wav',
#  '7_Kabira Full Song_ Yeh Jawaani Hai Deewani _ Pritam _ Ranbir Kapoor, Deepika Padukone.mp3',
#  "8 Rag'n'Bone Man - Human (Official Video).mp3",
#  '9 Passenger _ Let Her Go (Official Video).mp3']

# %%
files=os.listdir(PATH)
for file in files:
    path=PATH+file
    mc=MusicCluster(path)
    mc.results(k=3)
    del mc
#     br=input('Press 0 to break, Enter to continue')
#     if(br=='0'):
#         break
# Out:
# Clustering results for: data/0 Maroon 5 - Girls Like You ft. Cardi B (Volume 2) (Official Music Video).mp3
# Clustering complete!!
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# Clustering results for: data/1 debussy.wav
# Clustering complete!!
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# Clustering results for: data/2 queen.wav
# Clustering complete!!
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# Clustering results for: data/3 Wiz Khalifa - See You Again ft. Charlie Puth [Official Video] Furious 7 Soundtrack.mp3
# Clustering complete!!
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# Clustering results for: data/4 ZAYN - Dusk Till Dawn (Official Video) ft. Sia.mp3
# Clustering complete!!
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# Clustering results for: data/5 James Arthur - Say You Won't Let Go.mp3
# Clustering complete!!
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# Clustering results for: data/6 seeyouagain.wav
# Clustering complete!!
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# Clustering results for: data/7_Kabira Full Song_ Yeh Jawaani Hai Deewani _ Pritam _ Ranbir Kapoor, Deepika Padukone.mp3
# Clustering complete!!
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# Clustering results for: data/8 Rag'n'Bone Man - Human (Official Video).mp3
# Clustering complete!!
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# Clustering results for: data/9 Passenger _ Let Her Go (Official Video).mp3
# Clustering complete!!
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
